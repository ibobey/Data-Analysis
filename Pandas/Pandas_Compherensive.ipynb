# %% [markdown]
# <center> <h1 style="color:magenta"> Pandas Compherensive </h1> </center>

# %% [markdown]
# __Dataset:__ Pokemon Dataset

# %% [markdown]
# - pokemon_data.csv
# - pokemon_data.xlsx

# %% [markdown]
# __Installation for Another Environments__:

# %% [markdown]
# $ pip install numpy pandas matplotlib seaborn

# %% [markdown]
# __Import modules__:

# %%
import matplotlib.pyplot as plt
import numpy as np

import pandas as pd

# %% [markdown]
# <center> <h2 style="color:magenta"> Pandas Basics </h2> </center>

# %% [markdown]
# <center> <h3 style="color:magenta"> Loading Data </h3> </center>

# %%
pd.read_csv('pokemon_data.csv')
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander     Fire     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0         65       65     45           1      False
# ...

# %%
pd.read_excel('pokemon_data.xlsx')
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander     Fire     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0         65       65     45           1      False
# ...

# %% [markdown]
# __To load Data:__

# %%
dataset = pd.read_csv('pokemon_data.csv')

# %%
dataset
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander     Fire     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0         65       65     45           1      False
# ...

# %% [markdown]
# <center> <h3 style="color:magenta"> Data Overview </h3> </center>

# %%
type(dataset)
# Out:
# pandas.core.frame.DataFrame

# %%
dataset.head()
# Out:
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1              Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                Ivysaur  Grass  Poison  60      62       63       80
# 2  3               Venusaur  Grass  Poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4  4             Charmander   Fire     NaN  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary
# 0       65     45           1      False
# 1       80     60           1      False
# 2      100     80           1      False
# 3      120     80           1      False
# 4       50     65           1      False

# %%
dataset.tail()
# Out:
#        #                 Name   Type 1 Type 2  HP  Attack  Defense  Sp. Atk  \
# 795  719              Diancie     Rock  Fairy  50     100      150      100
# 796  719  DiancieMega Diancie     Rock  Fairy  50     160      110      160
# 797  720  HoopaHoopa Confined  Psychic  Ghost  80     110       60      150
# 798  720   HoopaHoopa Unbound  Psychic   Dark  80     160       60      170
# 799  721            Volcanion     Fire  Water  80     110      120      130
#
#      Sp. Def  Speed  Generation  Legendary
# 795      150     50           6       True
# 796      110    110           6       True
# 797      130     70           6       True
# 798      130     80           6       True
# 799       90     70           6       True

# %%
dataset.shape
# Out:
# (800, 12)

# %%
dataset.columns
# Out:
# Index(['#', 'Name', 'Type 1', 'Type 2', 'HP', 'Attack', 'Defense', 'Sp. Atk',
#        'Sp. Def', 'Speed', 'Generation', 'Legendary'],
#       dtype='object')

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 800 entries, 0 to 799
# Data columns (total 12 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   #           800 non-null    int64
#  1   Name        800 non-null    object
#  2   Type 1      800 non-null    object
#  3   Type 2      414 non-null    object
#  4   HP          800 non-null    int64
#  5   Attack      800 non-null    int64
#  6   Defense     800 non-null    int64
#  7   Sp. Atk     800 non-null    int64
#  8   Sp. Def     800 non-null    int64
#  9   Speed       800 non-null    int64
#  10  Generation  800 non-null    int64
#  11  Legendary   800 non-null    bool
# dtypes: bool(1), int64(8), object(3)
# memory usage: 69.7+ KB

# %%
dataset.describe()
# Out:
#                 #          HP      Attack     Defense     Sp. Atk     Sp. Def  \
# count  800.000000  800.000000  800.000000  800.000000  800.000000  800.000000
# mean   362.813750   69.258750   79.001250   73.842500   72.820000   71.902500
# std    208.343798   25.534669   32.457366   31.183501   32.722294   27.828916
# min      1.000000    1.000000    5.000000    5.000000   10.000000   20.000000
# 25%    184.750000   50.000000   55.000000   50.000000   49.750000   50.000000
# 50%    364.500000   65.000000   75.000000   70.000000   65.000000   70.000000
# 75%    539.250000   80.000000  100.000000   90.000000   95.000000   90.000000
# max    721.000000  255.000000  190.000000  230.000000  194.000000  230.000000
#
#             Speed  Generation
# count  800.000000   800.00000
# mean    68.277500     3.32375
# std     29.060474     1.66129
# min      5.000000     1.00000
# 25%     45.000000     2.00000
# 50%     65.000000     3.00000
# 75%     90.000000     5.00000
# ...

# %% [markdown]
# <center> <h3 style="color:magenta"> Reading Data </h3> </center>

# %%
dataset.columns
# Out:
# Index(['#', 'Name', 'Type 1', 'Type 2', 'HP', 'Attack', 'Defense', 'Sp. Atk',
#        'Sp. Def', 'Speed', 'Generation', 'Legendary'],
#       dtype='object')

# %%
dataset.HP
# Out:
# 0      45
# 1      60
# 2      80
# 3      80
# 4      39
#        ..
# 795    50
# 796    50
# 797    80
# 798    80
# 799    80
# Name: HP, Length: 800, dtype: int64

# %%
dataset['HP']
# Out:
# 0      45
# 1      60
# 2      80
# 3      80
# 4      39
#        ..
# 795    50
# 796    50
# 797    80
# 798    80
# 799    80
# Name: HP, Length: 800, dtype: int64

# %%
type(dataset.HP)
# Out:
# pandas.core.series.Series

# %%
dataset[['Name', 'HP']]
# Out:
#                       Name  HP
# 0                Bulbasaur  45
# 1                  Ivysaur  60
# 2                 Venusaur  80
# 3    VenusaurMega Venusaur  80
# 4               Charmander  39
# ..                     ...  ..
# 795                Diancie  50
# 796    DiancieMega Diancie  50
# 797    HoopaHoopa Confined  80
# 798     HoopaHoopa Unbound  80
# 799              Volcanion  80
#
# [800 rows x 2 columns]

# %%
type(dataset[['Name', 'HP']])
# Out:
# pandas.core.frame.DataFrame

# %%
dataset.iloc[0]
# Out:
# #                     1
# Name          Bulbasaur
# Type 1            Grass
# Type 2           Poison
# HP                   45
# Attack               49
# Defense              49
# Sp. Atk              65
# Sp. Def              65
# Speed                45
# Generation            1
# Legendary         False
# Name: 0, dtype: object

# %%
dataset.iloc[-1]
# Out:
# #                   721
# Name          Volcanion
# Type 1             Fire
# Type 2            Water
# HP                   80
# Attack              110
# Defense             120
# Sp. Atk             130
# Sp. Def              90
# Speed                70
# Generation            6
# Legendary          True
# Name: 799, dtype: object

# %%
dataset.loc[dataset.Generation == 6]
# Out:
#        #                 Name   Type 1    Type 2  HP  Attack  Defense  \
# 718  650              Chespin    Grass       NaN  56      61       65
# 719  651            Quilladin    Grass       NaN  61      78       95
# 720  652           Chesnaught    Grass  Fighting  88     107      122
# 721  653             Fennekin     Fire       NaN  40      45       40
# 722  654              Braixen     Fire       NaN  59      59       58
# ..   ...                  ...      ...       ...  ..     ...      ...
# 795  719              Diancie     Rock     Fairy  50     100      150
# 796  719  DiancieMega Diancie     Rock     Fairy  50     160      110
# 797  720  HoopaHoopa Confined  Psychic     Ghost  80     110       60
# 798  720   HoopaHoopa Unbound  Psychic      Dark  80     160       60
# 799  721            Volcanion     Fire     Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 718       48       45     38           6      False
# ...

# %%
dataset.loc[dataset.HP > 200]
# Out:
#        #     Name  Type 1 Type 2   HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 121  113  Chansey  Normal    NaN  250       5        5       35      105
# 261  242  Blissey  Normal    NaN  255      10       10       75      135
#
#      Speed  Generation  Legendary
# 121     50           1      False
# 261     55           2      False

# %%
dataset.loc[dataset.Name == 'Fennekin']
# Out:
#        #      Name Type 1 Type 2  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 721  653  Fennekin   Fire    NaN  40      45       40       62       60
#
#      Speed  Generation  Legendary
# 721     60           6      False

# %% [markdown]
# <center> <h3 style="color:magenta"> Sorting Data </h3> </center>

# %%
dataset.sort_values(['Type 1', 'HP'], ascending=[0,1])
# Out:
#        #                     Name Type 1    Type 2  HP  Attack  Defense  \
# 139  129                 Magikarp  Water       NaN  20      10       55
# 381  349                   Feebas  Water       NaN  20      15       20
# 97    90                 Shellder  Water       NaN  30      65      100
# 106   98                   Krabby  Water       NaN  30     105       90
# 125  116                   Horsea  Water       NaN  30      40       70
# ..   ...                      ...    ...       ...  ..     ...      ...
# 232  214  HeracrossMega Heracross    Bug  Fighting  80     185      115
# 678  617                 Accelgor    Bug       NaN  80      70       40
# 734  666                 Vivillon    Bug    Flying  80      52       50
# 698  637                Volcarona    Bug      Fire  85      60       65
# 520  469                  Yanmega    Bug    Flying  86      76       86
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# ...

# %%
dataset.sort_values(['Type 1', 'HP'], ascending=[1,1])
# Out:
#        #       Name Type 1  Type 2   HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 316  292   Shedinja    Bug   Ghost    1      90       45       30       30
# 230  213    Shuckle    Bug    Rock   20      10      230       10      230
# 462  415     Combee    Bug  Flying   30      30       42       30       42
# 603  543   Venipede    Bug  Poison   30      45       59       30       39
# 314  290    Nincada    Bug  Ground   31      45       90       30       30
# ..   ...        ...    ...     ...  ...     ...      ...      ...      ...
# 142  131     Lapras  Water     Ice  130      85       80       85       95
# 145  134   Vaporeon  Water     NaN  130      65       60      110       95
# 350  320    Wailmer  Water     NaN  130      70       35       70       35
# 655  594  Alomomola  Water     NaN  165      75       80       40       45
# 351  321    Wailord  Water     NaN  170      90       45       90       45
#
#      Speed  Generation  Legendary
# ...

# %%
dataset.sort_values(['Attack'], ascending=0)
# Out:
#        #                     Name   Type 1    Type 2   HP  Attack  Defense  \
# 163  150      MewtwoMega Mewtwo X  Psychic  Fighting  106     190      100
# 232  214  HeracrossMega Heracross      Bug  Fighting   80     185      115
# 424  383    GroudonPrimal Groudon   Ground      Fire  100     180      160
# 426  384    RayquazaMega Rayquaza   Dragon    Flying  105     180      100
# 429  386       DeoxysAttack Forme  Psychic       NaN   50     180       20
# ..   ...                      ...      ...       ...  ...     ...      ...
# 139  129                 Magikarp    Water       NaN   20      10       55
# 261  242                  Blissey   Normal       NaN  255      10       10
# 230  213                  Shuckle      Bug      Rock   20      10      230
# 121  113                  Chansey   Normal       NaN  250       5        5
# 488  440                  Happiny   Normal       NaN  100       5        5
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# ...

# %% [markdown]
# <center> <h3 style="color:magenta"> Altering Data </h3> </center>

# %%
dataset['TotalPower'] = dataset.HP + dataset.Defense + dataset.Speed

# %%
dataset.sort_values(['TotalPower'], ascending=0)
# Out:
#        #                   Name   Type 1  Type 2   HP  Attack  Defense  \
# 552  493                 Arceus   Normal     NaN  120     120      120
# 544  487  GiratinaAltered Forme    Ghost  Dragon  150     100      120
# 424  383  GroudonPrimal Groudon   Ground    Fire  100     180      160
# 333  306      AggronMega Aggron    Steel     NaN   70     140      230
# 313  289                Slaking   Normal     NaN  150     160      100
# ..   ...                    ...      ...     ...  ...     ...      ...
# 303  280                  Ralts  Psychic   Fairy   28      25       25
# 187  173                 Cleffa    Fairy     NaN   50      25       28
# 206  191                Sunkern    Grass     NaN   30      30       30
# 175  161                Sentret   Normal     NaN   35      46       34
# 316  292               Shedinja      Bug   Ghost    1      90       45
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary  TotalPower
# ...

# %% [markdown]
# <center> <h3 style="color:magenta"> Filtering Data </h3> </center>

# %%
dataset.loc[(dataset['Type 1'] == 'Normal') & (dataset.TotalPower > 120)]
# Out:
#        #                     Name  Type 1    Type 2   HP  Attack  Defense  \
# 20    16                   Pidgey  Normal    Flying   40      45       40
# 21    17                Pidgeotto  Normal    Flying   63      60       55
# 22    18                  Pidgeot  Normal    Flying   83      80       75
# 23    18      PidgeotMega Pidgeot  Normal    Flying   83      80       80
# 24    19                  Rattata  Normal       NaN   30      56       35
# ..   ...                      ...     ...       ...  ...     ...      ...
# 716  648  MeloettaPirouette Forme  Normal  Fighting  100     128       90
# 727  659                 Bunnelby  Normal       NaN   38      36       38
# 728  660                Diggersby  Normal    Ground   85      56       77
# 729  661               Fletchling  Normal    Flying   45      50       43
# 744  676                  Furfrou  Normal       NaN   75      80       60
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary  TotalPower
# ...

# %%
# new_data = dataset.loc[(dataset['Type 1'] == 'Normal') & (dataset.TotalPower > 120)]
# new_data.to_csv('new_data.csv')

# %% [markdown]
# <center> <h3 style="color:magenta"> Conditional Changes </h3> </center>

# %%
dataset.loc[dataset['TotalPower'] > 300, ['Generation', 'Legendary']] = ['Test 1', 'Test 2']

# %%
dataset.sort_values(['TotalPower'], ascending=0)
# Out:
#        #                   Name   Type 1  Type 2   HP  Attack  Defense  \
# 552  493                 Arceus   Normal     NaN  120     120      120
# 544  487  GiratinaAltered Forme    Ghost  Dragon  150     100      120
# 424  383  GroudonPrimal Groudon   Ground    Fire  100     180      160
# 333  306      AggronMega Aggron    Steel     NaN   70     140      230
# 313  289                Slaking   Normal     NaN  150     160      100
# ..   ...                    ...      ...     ...  ...     ...      ...
# 303  280                  Ralts  Psychic   Fairy   28      25       25
# 187  173                 Cleffa    Fairy     NaN   50      25       28
# 206  191                Sunkern    Grass     NaN   30      30       30
# 175  161                Sentret   Normal     NaN   35      46       34
# 316  292               Shedinja      Bug   Ghost    1      90       45
#
#      Sp. Atk  Sp. Def  Speed Generation Legendary  TotalPower
# ...

# %% [markdown]
# <center> <h3 style="color:magenta"> Grouping Data </h3> </center>

# %%
dataset.columns
# Out:
# Index(['#', 'Name', 'Type 1', 'Type 2', 'HP', 'Attack', 'Defense', 'Sp. Atk',
#        'Sp. Def', 'Speed', 'Generation', 'Legendary', 'TotalPower'],
#       dtype='object')

# %%
dataset['Type 1'].unique()
# Out:
# array(['Grass', 'Fire', 'Water', 'Bug', 'Normal', 'Poison', 'Electric',
#        'Ground', 'Fairy', 'Fighting', 'Psychic', 'Rock', 'Ghost', 'Ice',
#        'Dragon', 'Dark', 'Steel', 'Flying'], dtype=object)

# %%
dataset['Type 2'].unique()
# Out:
# array(['Poison', nan, 'Flying', 'Dragon', 'Ground', 'Fairy', 'Grass',
#        'Fighting', 'Psychic', 'Steel', 'Ice', 'Rock', 'Dark', 'Water',
#        'Electric', 'Fire', 'Ghost', 'Bug', 'Normal'], dtype=object)

# %%
dataset.groupby(['Type 1']).count()
# Out:
#             #  Name  Type 2   HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  \
# Type 1
# Bug        69    69      52   69      69       69       69       69     69
# Dark       31    31      21   31      31       31       31       31     31
# Dragon     32    32      21   32      32       32       32       32     32
# Electric   44    44      17   44      44       44       44       44     44
# Fairy      17    17       2   17      17       17       17       17     17
# Fighting   27    27       7   27      27       27       27       27     27
# Fire       52    52      24   52      52       52       52       52     52
# Flying      4     4       2    4       4        4        4        4      4
# Ghost      32    32      22   32      32       32       32       32     32
# Grass      70    70      37   70      70       70       70       70     70
# Ground     32    32      19   32      32       32       32       32     32
# ...

# %% [markdown]
# __Dropping Column__:

# %%
dataset.drop(columns='#')
# Out:
#                       Name   Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0                Bulbasaur    Grass  Poison  45      49       49       65
# 1                  Ivysaur    Grass  Poison  60      62       63       80
# 2                 Venusaur    Grass  Poison  80      82       83      100
# 3    VenusaurMega Venusaur    Grass  Poison  80     100      123      122
# 4               Charmander     Fire     NaN  39      52       43       60
# ..                     ...      ...     ...  ..     ...      ...      ...
# 795                Diancie     Rock   Fairy  50     100      150      100
# 796    DiancieMega Diancie     Rock   Fairy  50     160      110      160
# 797    HoopaHoopa Confined  Psychic   Ghost  80     110       60      150
# 798     HoopaHoopa Unbound  Psychic    Dark  80     160       60      170
# 799              Volcanion     Fire   Water  80     110      120      130
#
#      Sp. Def  Speed Generation Legendary  TotalPower
# ...

# %%
dataset
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander     Fire     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed Generation Legendary  TotalPower
# 0         65       65     45          1     False         139
# ...

# %%
dataset.drop(columns='#', inplace=True)

# %%
dataset.groupby(['Type 1', 'Type 2']).count()
# Out:
#                  Name  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  \
# Type 1 Type 2
# Bug    Electric     2   2       2        2        2        2      2
#        Fighting     2   2       2        2        2        2      2
#        Fire         2   2       2        2        2        2      2
#        Flying      14  14      14       14       14       14     14
#        Ghost        1   1       1        1        1        1      1
# ...               ...  ..     ...      ...      ...      ...    ...
# Water  Ice          3   3       3        3        3        3      3
#        Poison       3   3       3        3        3        3      3
#        Psychic      5   5       5        5        5        5      5
#        Rock         4   4       4        4        4        4      4
#        Steel        1   1       1        1        1        1      1
#
#                  Generation  Legendary  TotalPower
# Type 1 Type 2
# Bug    Electric           2          2           2
# ...

# %% [markdown]
# <center> <h3 style="color:magenta"> Null Values </h3> </center>

# %%
dataset.isna()
# Out:
#       Name  Type 1  Type 2     HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  \
# 0    False   False   False  False   False    False    False    False  False
# 1    False   False   False  False   False    False    False    False  False
# 2    False   False   False  False   False    False    False    False  False
# 3    False   False   False  False   False    False    False    False  False
# 4    False   False    True  False   False    False    False    False  False
# ..     ...     ...     ...    ...     ...      ...      ...      ...    ...
# 795  False   False   False  False   False    False    False    False  False
# 796  False   False   False  False   False    False    False    False  False
# 797  False   False   False  False   False    False    False    False  False
# 798  False   False   False  False   False    False    False    False  False
# 799  False   False   False  False   False    False    False    False  False
#
#      Generation  Legendary  TotalPower
# ...

# %%
dataset.isna().sum()
# Out:
# Name            0
# Type 1          0
# Type 2        386
# HP              0
# Attack          0
# Defense         0
# Sp. Atk         0
# Sp. Def         0
# Speed           0
# Generation      0
# Legendary       0
# TotalPower      0
# dtype: int64

# %%
dataset['Type 2']= dataset['Type 2'].fillna(-1)

# %%
dataset.isna().sum()
# Out:
# Name          0
# Type 1        0
# Type 2        0
# HP            0
# Attack        0
# Defense       0
# Sp. Atk       0
# Sp. Def       0
# Speed         0
# Generation    0
# Legendary     0
# TotalPower    0
# dtype: int64

# %%
## !!! Caution

# %% [markdown]
# <center> <h3 style="color:magenta"> Statistical Operations </h3> </center>

# %% [markdown]
# <center> <h3 style="color:magenta"> Analyzing Data </h3> </center>
